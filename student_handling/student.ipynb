# %%
# # ## Write student records.
# # Append new student records.
# # Read complete records.
# # Read individual lines.
# # Count number of records.
# # Copy data into another backup file.
# # Create
# # students_backup.txt
# # Create another file containing only names and courses.

# data = """101,Sudhanshu,sudh@example.com,9999999999,Python,Bangalore
# 102,Rahul,rahul@example.com,8888888888,Data Science,Delhi
# 103,Priya,priya@example.com,7777777777,Java,Mumbai
# 104,Amit,amit@example.com,6666666666,Web Development,Pune
# 105,Sneha,sneha@example.com,5555555555,Machine Learning,Hyderabad
# 106,Karan,karan@example.com,4444444444,DevOps,Chennai
# 107,Neha,neha@example.com,3333333333,SQL,Kolkata
# 108,Vikram,vikram@example.com,2222222222,Django,Ahmedabad
# 109,Anjali,anjali@example.com,1111111111,Data Analysis,Noida
# 110,Rohan,rohan@example.com,9876543210,Cloud Computing,Gurgaon
# """

# %%
data = """101,Sudhanshu,sudh@example.com,9999999999,Python,Bangalore
102,Rahul,rahul@example.com,8888888888,Data Science,Delhi
103,Priya,priya@example.com,7777777777,Java,Mumbai
104,Amit,amit@example.com,6666666666,Web Development,Pune
105,Sneha,sneha@example.com,5555555555,Machine Learning,Hyderabad
106,Karan,karan@example.com,4444444444,DevOps,Chennai
107,Neha,neha@example.com,3333333333,SQL,Kolkata
108,Vikram,vikram@example.com,2222222222,Django,Ahmedabad
109,Anjali,anjali@example.com,1111111111,Data Analysis,Noida"""

# %%
with open("student.txt", "w") as file:
    file.write(data)

# %%
with open("student.txt","a") as file:
    file.write("\n110,Rohan,rohan@example.com,9876543210,Cloud Computing,Gurgaon\n")

# %%
with open("student.txt","r") as file:
    lines= file.readlines()

# %%
print(lines)
# Out:
# ['101,Sudhanshu,sudh@example.com,9999999999,Python,Bangalore\n', '102,Rahul,rahul@example.com,8888888888,Data Science,Delhi\n', '103,Priya,priya@example.com,7777777777,Java,Mumbai\n', '104,Amit,amit@example.com,6666666666,Web Development,Pune\n', '105,Sneha,sneha@example.com,5555555555,Machine Learning,Hyderabad\n', '106,Karan,karan@example.com,4444444444,DevOps,Chennai\n', '107,Neha,neha@example.com,3333333333,SQL,Kolkata\n', '108,Vikram,vikram@example.com,2222222222,Django,Ahmedabad\n', '109,Anjali,anjali@example.com,1111111111,Data Analysis,Noida\n', '110,Rohan,rohan@example.com,9876543210,Cloud Computing,Gurgaon\n']

# %%
for i in lines:
    print(i)
# Out:
# 101,Sudhanshu,sudh@example.com,9999999999,Python,Bangalore
#
# 102,Rahul,rahul@example.com,8888888888,Data Science,Delhi
#
# 103,Priya,priya@example.com,7777777777,Java,Mumbai
#
# 104,Amit,amit@example.com,6666666666,Web Development,Pune
#
# 105,Sneha,sneha@example.com,5555555555,Machine Learning,Hyderabad
#
# 106,Karan,karan@example.com,4444444444,DevOps,Chennai
#
# 107,Neha,neha@example.com,3333333333,SQL,Kolkata
#
# 108,Vikram,vikram@example.com,2222222222,Django,Ahmedabad
#
# 109,Anjali,anjali@example.com,1111111111,Data Analysis,Noida
#
# 110,Rohan,rohan@example.com,9876543210,Cloud Computing,Gurgaon

# %%
## count the number of records
len(lines)
# Out:
# 10

# %%
with open("student_backup.txt","w") as file:
    for i in lines:
        file.write(i)

# %%
with open("student_name_place.txt", "w")as file:
    name=[]
    place=[]
    for i in lines:
        name=i.strip().split(",")[1]
        place= i.strip().split(",")[4]
        file.write(f"{name} : {place}\n")
