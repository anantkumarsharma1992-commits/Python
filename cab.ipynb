# %%
class vehicle:
    def __init__(self, veh_no, brand, driver_name,priceperkm):
        self.vehical_no= veh_no
        self.brand= brand
        self.driver_name= driver_name
        self.priceperkm= priceperkm

# %%
class bike(vehicle):
    
    def __init__(self, veh_no, brand, driver_name,priceperkm):
        super(). __init__(veh_no,brand,driver_name,priceperkm)

    def display_info(self,distance):
        fare= distance* self.priceperkm
        print(f"the vehicle has been book with {self.vehical_no} from brand {self.brand}. The driver is {self.driver_name} and the price per km will be {self.priceperkm}. Your total fare is {fare}")

# %%
class car(vehicle):
    
    def __init__(self, veh_no, brand, driver_name,priceperkm):
        super(). __init__(veh_no,brand,driver_name,priceperkm)

    def display_info(self,distance):
        fare= distance* self.priceperkm
        print(f"the vehicle has been book with {self.vehical_no} from brand {self.brand}. The driver is {self.driver_name} and the price per km will be {self.priceperkm}. Your total fare is {fare}")

# %%
car1 = car("MH12AB1234", "Toyota", "Rahul", 20)
car2 = car("MH14XY5678", "Honda", "Amit", 25)

bike1 = bike("MH13CD4321", "Yamaha", "Suresh", 10)
bike2 = bike("MH15EF8765", "Bajaj", "Ramesh", 12)

# %%
car1.display_info(22)
# Out:
# the vehicle has been book with MH12AB1234 from brand Toyota. The driver is Rahul and the price per km will be 20. Your total fare is 440

# %%
car2.display_info(32)
# Out:
# the vehicle has been book with MH14XY5678 from brand Honda. The driver is Amit and the price per km will be 25. Your total fare is 800

# %%
bike1.display_info(45)
# Out:
# the vehicle has been book with MH13CD4321 from brand Yamaha. The driver is Suresh and the price per km will be 10. Your total fare is 450

# %%
bike2.display_info(4)
# Out:
# the vehicle has been book with MH15EF8765 from brand Bajaj. The driver is Ramesh and the price per km will be 12. Your total fare is 48
