# %%
#     # "Line 1: Welcome to my notes file.\n",
#     # "Line 2: Python file handling is easy.\n",
#     # "Line 3: open() lets us access a file.\n",
#     # "Line 4: write() adds text to a file.\n",
#     # "Line 5: read() lets us view file content.\n",
#     # "Line 6: close() releases the file resource.\n",
#     # "Line 7: 'w' mode overwrites existing content.\n",
#     # "Line 8: 'a' mode appends without deleting data.\n",
#     # "Line 9: 'r' mode is used only for reading.\n",
#     # "Line 10: This is the last line of the first write.\n",

#     open() read() write() append() close() Create a file notes.txt 
#     Creating the file.
# Writing at least 10 lines.
# Reading the entire file.
# Reading only a specific number of characters.
# Using readline().
# Using readlines().
# Reopening the file and displaying updated contents.

# %%
file= open("notes.txt","w")

# %%
file.write("This is my first document\n")
file.close()

# %%
file= open("notes.txt","r")
file.read()
file.close()

# %%
file= open("notes.txt","w")

# %%
line= """ Line 1: Welcome to my notes file,
Line 2: Python file handling is easy.
Line 3: open() lets us access a file.
Line 4: write() adds text to a file.
Line 5: read() lets us view file content.
Line 6: close() releases the file resource.
Line 7: 'w' mode overwrites existing content.
Line 8: 'a' mode appends without deleting data.
Line 9: 'r' mode is used only for reading.
Line 10: This is the last line of the first write."""

# %%
file.write(line)
file.close()

# %%
file= open("notes.txt","r")
file.read()
file.close()

# %%
file= open("notes.txt","r")
file.read(40)
file.close()

# %%
file= open("notes.txt","a")
file.write("line 11: This is me appending in the existing document\n")
file.close()

# %%
file= open("notes.txt","a")
file.write("\nline 12: This is me appending in the existing document\n")
file.close()

# %%
file= open("notes.txt","r")
file.readline()
file.close()

# %%
file= open("notes.txt","r")
file.readlines()
file.close()

# %%
with open("notes.txt","r") as file:
    content= file.readlines()

# %%
print(content)
# Out:
# [' Line 1: Welcome to my notes file,\n', 'Line 2: Python file handling is easy.\n', 'Line 3: open() lets us access a file.\n', 'Line 4: write() adds text to a file.\n', 'Line 5: read() lets us view file content.\n', 'Line 6: close() releases the file resource.\n', "Line 7: 'w' mode overwrites existing content.\n", "Line 8: 'a' mode appends without deleting data.\n", "Line 9: 'r' mode is used only for reading.\n", 'Line 10: This is the last line of the first write.line 11: This is me appending in the existing document\n', '\n', 'line 12: This is me appending in the existing document\n', 'line 11: This is me appending in the existing document\n']
